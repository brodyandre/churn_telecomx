# %% [markdown]
# <a href="https://colab.research.google.com/github/brodyandre/churn_telecomx/blob/main/churn_telecom_x.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Sumário Interativo
#
# <a name="indice"></a>
#
# - [📉 Etapa 1: Estudo de Churn - Telecom X](#etapa-1-estudo-de-churn---telecom-x)
# - [🚀 Etapa 2: Carregando e Normalizando os Dados JSON](#etapa-2-carregando-e-normalizando-os-dados-json)
# - [📥 Etapa 3: Carregamento dos Dados](#etapa-3-carregamento-dos-dados)
# - [🔍 Etapa 4: Análise Exploratória dos Dados (EDA)](#etapa-4-análise-exploratória-dos-dados-eda)
# - [🔄 Etapa 5: Normalização dos Dados Aninhados](#etapa-5-normalização-dos-dados-aninhados)
# - [📦 Etapa 6: Expansão da Coluna Charges](#etapa-6-expansão-da-coluna-charges)
# - [🚀 Etapa 7: Análise Exploratória Visual do Churn da Telecom X](#etapa-7-análise-exploratória-visual-do-churn-da-telecom-x)
# - [🎯 Etapa 8: Gráfico 2: Distribuição de Churn por Tipo de Contrato](#etapa-8-gráfico-2-distribuição-de-churn-por-tipo-de-contrato)
# - [📊 Etapa 9: Gráfico 3: Cancelamentos por Método de Pagamento](#etapa-9-gráfico-3-cancelamentos-por-método-de-pagamento)
# - [🌐 Etapa 10: Gráfico 4: Cancelamentos por Tipo de Internet](#etapa-10-gráfico-4-cancelamentos-por-tipo-de-internet)
# - [📞 Etapa 11: Gráfico: Churn por Serviço de Telefonia](#etapa-11-gráfico-churn-por-serviço-de-telefonia)
# - [💳 Etapa 12: Gráfico: Churn por Forma de Pagamento](#etapa-12-gráfico-churn-por-forma-de-pagamento)
# - [📡 Etapa 13: Gráfico: Churn por Tipo de Internet](#etapa-13-gráfico-churn-por-tipo-de-internet)
# - [💰 Etapa 14: Gráfico: Distribuição dos Valores Mensais com Churn](#etapa-14-gráfico-distribuição-dos-valores-mensais-com-churn)
# - [📊 Etapa 15: Análise do Tempo de Permanência dos Clientes e Churn ⏳](#etapa-15-análise-do-tempo-de-permanência-dos-clientes-e-churn-)
# - [📊 Etapa 16: Gráfico — Taxa de Churn por Tipo de Contrato](#etapa-16-gráfico-—-taxa-de-churn-por-tipo-de-contrato)
# - [📅 Etapa 17: Gráfico: Taxa de Churn por Tempo de Contrato (tenure)](#etapa-17-gráfico-taxa-de-churn-por-tempo-de-contrato-tenure)
# - [📈 Etapa 18: Um breve relatório descritivo do grafico de Churn por tempo de contrato - Telecom X](#etapa-18-um-breve-relatorio-descritivo-do-grafico-de-churn-por-tempo-de-contrato---telecom-x)
# - [📈 Etapa 19: Análise de Churn - Telecom X](#etapa-19-análise-de-churn---telecom-x)
# - [📥 Etapa 20: Download do Relatório](#etapa-20-download-do-relatório)
# - [🔜 Etapa 21: Próximo Passo: Pré-processamento para Machine Learning](#etapa-21-próximo-passo-pré-processamento-para-machine-learning)
# - [🎯 Etapa 22: Modelo de Classificação com Random Forest e Balanceamento de Classes usando SMOTE](#etapa-22-modelo-de-classificação-com-random-forest-e-balanceamento-de-classes-usando-smote)
# - [📊 Etapa 23: Análise da Importância das Features no Modelo Random Forest](#etapa-23-análise-da-importância-das-features-no-modelo-random-forest)
# - [🎯 Etapa 24: Treinamento e Avaliação do Modelo Random Forest com as 10 Features Mais Importantes](#etapa-24-treinamento-e-avaliação-do-modelo-random-forest-com-as-10-features-mais-importantes)
# - [📊 Etapa 25: Avaliação do Modelo com Ajuste de Threshold e Curvas ROC / Precision-Recall](#etapa-25-avaliação-do-modelo-com-ajuste-de-threshold-e-curvas-roc--precision-recall)
# - [✅ Etapa 26: Resumo do Que o Código acima Faz](#etapa-26-resumo-do-que-o-código-acima-faz)
# - [🚦 Etapa 27: Função para Avaliação do Modelo com Threshold Personalizado](#etapa-27-função-para-avaliação-do-modelo-com-threshold-personalizado)
# - [📈 Etapa 28: Predição e Avaliação com Threshold Customizado e Salvamento em CSV](#etapa-28-predição-e-avaliação-com-threshold-customizado-e-salvamento-em-csv)
# - [🔍 Etapa 29: Predição e Avaliação com Threshold Personalizado e Salvamento em CSV](#etapa-29-predição-e-avaliação-com-threshold-personalizado-e-salvamento-em-csv)
# - [📈 Etapa 30: Avaliação de Métricas em Vários Thresholds e Visualização Gráfica](#etapa-30-avaliação-de-métricas-em-vários-thresholds-e-visualização-gráfica)
# - [📊 Etapa 31: Relatório de Análise dos Thresholds para Previsão de Churn – TelecomX](#etapa-31-relatório-de-análise-dos-thresholds-para-previsão-de-churn--telecomx)

# %% [markdown]
# <a name="etapa-1-estudo-de-churn---telecom-x"></a>
# # 📉 Etapa 1: Estudo de Churn - Telecom X

# %% [markdown]
# Este projeto foi desenvolvido por Luiz André, com o objetivo de analisar e prever a evasão de clientes (*churn*) da empresa Telecom X. O modelo final será preparado para ser implementado em uma aplicação web com **Streamlit**.
#
# ---
#
# 🔎 **Objetivos**:
# - Compreender padrões de cancelamento.
# - Criar um modelo de machine learning para prever churn.
# - Fornecer insights para retenção de clientes.
#
# 📦 **Fonte de dados**: [TelecomX_Data.json](https://raw.githubusercontent.com/alura-cursos/challenge2-data-science/refs/heads/main/TelecomX_Data.json)

# %% [markdown]
# [🔝 Voltar ao Sumário](#indice)

# %% [markdown]
# <a name="etapa-2-carregando-e-normalizando-os-dados-json"></a>
# # 🚀 Etapa 2: Carregando e Normalizando os Dados JSON

# %%
import pandas as pd
import requests

# URL do JSON
url = "https://raw.githubusercontent.com/alura-cursos/challenge2-data-science/refs/heads/main/TelecomX_Data.json"

# Lendo os dados diretamente do JSON
df_raw = pd.read_json(url)
df_raw.head()
# Out:
#    customerID Churn                                           customer  \
# 0  0002-ORFBO    No  {'gender': 'Female', 'SeniorCitizen': 0, 'Part...
# 1  0003-MKNFE    No  {'gender': 'Male', 'SeniorCitizen': 0, 'Partne...
# 2  0004-TLHLJ   Yes  {'gender': 'Male', 'SeniorCitizen': 0, 'Partne...
# 3  0011-IGKFF   Yes  {'gender': 'Male', 'SeniorCitizen': 1, 'Partne...
# 4  0013-EXCHZ   Yes  {'gender': 'Female', 'SeniorCitizen': 1, 'Part...
#
#                                              phone  \
# 0   {'PhoneService': 'Yes', 'MultipleLines': 'No'}
# 1  {'PhoneService': 'Yes', 'MultipleLines': 'Yes'}
# 2   {'PhoneService': 'Yes', 'MultipleLines': 'No'}
# 3   {'PhoneService': 'Yes', 'MultipleLines': 'No'}
# 4   {'PhoneService': 'Yes', 'MultipleLines': 'No'}
#
#                                             internet  \
# 0  {'InternetService': 'DSL', 'OnlineSecurity': '...
# 1  {'InternetService': 'DSL', 'OnlineSecurity': '...
# 2  {'InternetService': 'Fiber optic', 'OnlineSecu...
# ...

# %% [markdown]
# [🔝 Voltar ao Sumário](#indice)

# %% [markdown]
# <a name="etapa-3-carregamento-dos-dados"></a>
# # 📥 Etapa 3: Carregamento dos Dados

# %% [markdown]
# O dataset JSON da Telecom X já vem em formato tabular (plano), o que facilita a leitura direta com `pandas.read_json`.
#
# Fonte: [TelecomX_Data.json](https://raw.githubusercontent.com/alura-cursos/challenge2-data-science/refs/heads/main/TelecomX_Data.json)

# %%
# URL do JSON
url = "https://raw.githubusercontent.com/alura-cursos/challenge2-data-science/refs/heads/main/TelecomX_Data.json"

# Lendo os dados do JSON (já plano)
df = pd.read_json(url)

# Visualizar as primeiras linhas
df.head()
# Out:
#    customerID Churn                                           customer  \
# 0  0002-ORFBO    No  {'gender': 'Female', 'SeniorCitizen': 0, 'Part...
# 1  0003-MKNFE    No  {'gender': 'Male', 'SeniorCitizen': 0, 'Partne...
# 2  0004-TLHLJ   Yes  {'gender': 'Male', 'SeniorCitizen': 0, 'Partne...
# 3  0011-IGKFF   Yes  {'gender': 'Male', 'SeniorCitizen': 1, 'Partne...
# 4  0013-EXCHZ   Yes  {'gender': 'Female', 'SeniorCitizen': 1, 'Part...
#
#                                              phone  \
# 0   {'PhoneService': 'Yes', 'MultipleLines': 'No'}
# 1  {'PhoneService': 'Yes', 'MultipleLines': 'Yes'}
# 2   {'PhoneService': 'Yes', 'MultipleLines': 'No'}
# 3   {'PhoneService': 'Yes', 'MultipleLines': 'No'}
# 4   {'PhoneService': 'Yes', 'MultipleLines': 'No'}
#
#                                             internet  \
# 0  {'InternetService': 'DSL', 'OnlineSecurity': '...
# 1  {'InternetService': 'DSL', 'OnlineSecurity': '...
# 2  {'InternetService': 'Fiber optic', 'OnlineSecu...
# ...

# %%
# Normalizando os dados aninhados
# df = pd.json_normalize(df_raw["clientes"]) # Comment out or remove this line
# df.head() # Comment out or remove this line

# Print the columns of df_raw to inspect them
print(df_raw.columns)
# Out:
# Index(['customerID', 'Churn', 'customer', 'phone', 'internet', 'account'], dtype='object')

# %% [markdown]
# [🔝 Voltar ao Sumário](#indice)

# %% [markdown]
# <a name="etapa-4-análise-exploratória-dos-dados-eda"></a>
# # 🔍 Etapa 4: Análise Exploratória dos Dados (EDA)

# %% [markdown]
# Nesta etapa, vamos explorar visualmente e estatisticamente os dados para entender o comportamento dos clientes da Telecom X e identificar padrões relacionados ao churn (cancelamento).

# %% [markdown]
# ✅ 4.1. Informações iniciais sobre os dados

# %%
# Informações gerais do DataFrame
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7267 entries, 0 to 7266
# Data columns (total 6 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   customerID  7267 non-null   object
#  1   Churn       7267 non-null   object
#  2   customer    7267 non-null   object
#  3   phone       7267 non-null   object
#  4   internet    7267 non-null   object
#  5   account     7267 non-null   object
# dtypes: object(6)
# memory usage: 340.8+ KB

# %%
# Estatísticas descritivas
df.describe(include='all')
# Out:
#         customerID Churn                                           customer  \
# count         7267  7267                                               7267
# unique        7267     3                                                891
# top     9995-HOTOH    No  {'gender': 'Male', 'SeniorCitizen': 0, 'Partne...
# freq             1  5174                                                223
#
#                                                  phone  \
# count                                             7267
# unique                                               3
# top     {'PhoneService': 'Yes', 'MultipleLines': 'No'}
# freq                                              3495
#
#                                                  internet  \
# count                                                7267
# unique                                                129
# top     {'InternetService': 'No', 'OnlineSecurity': 'N...
# freq                                                 1581
#
# ...

# %% [markdown]
# [🔝 Voltar ao Sumário](#indice)

# %% [markdown]
# <a name="etapa-5-normalização-dos-dados-aninhados"></a>
# # 🔄 Etapa 5: Normalização dos Dados Aninhados

# %% [markdown]
# Embora o dataset parecesse plano à primeira vista, algumas colunas como `customer`, `phone`, `internet` e `account` continham dados no formato JSON (dicionários). Utilizamos `pandas.Series` para expandir essas colunas e transformar cada chave em uma coluna individual.

# %%
# Expande as colunas aninhadas
df_expandido = pd.concat([
    df_raw.drop(columns=['customer', 'phone', 'internet', 'account']),
    df_raw['customer'].apply(pd.Series),
    df_raw['phone'].apply(pd.Series),
    df_raw['internet'].apply(pd.Series),
    df_raw['account'].apply(pd.Series)
], axis=1)

# Renomeando a coluna ID para padronizar
df_expandido.rename(columns={"customerID": "id_cliente"}, inplace=True)

# Visualiza os dados normalizados
df_expandido.head()
# Out:
#    id_cliente Churn  gender  SeniorCitizen Partner Dependents  tenure  \
# 0  0002-ORFBO    No  Female              0     Yes        Yes       9
# 1  0003-MKNFE    No    Male              0      No         No       9
# 2  0004-TLHLJ   Yes    Male              0      No         No       4
# 3  0011-IGKFF   Yes    Male              1     Yes         No      13
# 4  0013-EXCHZ   Yes  Female              1     Yes         No       3
#
#   PhoneService MultipleLines InternetService OnlineSecurity OnlineBackup  \
# 0          Yes            No             DSL             No          Yes
# 1          Yes           Yes             DSL             No           No
# 2          Yes            No     Fiber optic             No           No
# 3          Yes            No     Fiber optic             No          Yes
# 4          Yes            No     Fiber optic             No           No
#
#   DeviceProtection TechSupport StreamingTV StreamingMovies        Contract  \
# ...

# %% [markdown]
# [🔝 Voltar ao Sumário](#indice)

# %% [markdown]
# <a name="etapa-6-expansão-da-coluna-charges"></a>
# # 📦 Etapa 6: Expansão da Coluna Charges

# %% [markdown]
# A coluna `Charges` armazenava dois valores financeiros: o valor mensal e o valor total gasto pelo cliente. Para facilitar a análise, separamos essas informações em duas colunas distintas: `valor_mensal` e `valor_total`. Também realizamos a conversão da coluna `valor_total` para tipo numérico.

# %%
# Verifique as colunas dentro da coluna 'account'
print(df_raw['account'].apply(pd.Series).columns)
# Out:
# Index(['Contract', 'PaperlessBilling', 'PaymentMethod', 'Charges'], dtype='object')

# %%
# URL do arquivo JSON
url = "https://raw.githubusercontent.com/alura-cursos/challenge2-data-science/refs/heads/main/TelecomX_Data.json"

# Lê o JSON
df_raw = pd.read_json(url)

# 1. Expande as colunas aninhadas exceto 'Charges'
df_expandido = pd.concat([
    df_raw.drop(columns=['customer', 'phone', 'internet', 'account']),
    df_raw['customer'].apply(pd.Series),
    df_raw['phone'].apply(pd.Series),
    df_raw['internet'].apply(pd.Series),
    df_raw['account'].apply(pd.Series)
], axis=1)

# 2. Expande a coluna 'Charges' dentro da coluna 'account'
df_expandido = pd.concat([
    df_expandido.drop(columns=['Charges']),
    df_expandido['Charges'].apply(pd.Series)
], axis=1)

# 3. Renomeia as colunas de valores mensais e totais
df_expandido = df_expandido.rename(columns={
    'Monthly': 'valor_mensal',
    'Total': 'valor_total'
})

# 4. Converte 'valor_mensal' e 'valor_total' para float, tratando erros e NaNs
df_expandido['valor_mensal'] = pd.to_numeric(df_expandido['valor_mensal'], errors='coerce').fillna(0)
df_expandido['valor_total'] = pd.to_numeric(df_expandido['valor_total'], errors='coerce').fillna(0)

# 5. Renomeia coluna de ID
df_expandido = df_expandido.rename(columns={"customerID": "id_cliente"})

# 6. Exibe as 5 primeiras linhas como DataFrame
df_expandido.head()
# Out:
#    id_cliente Churn  gender  SeniorCitizen Partner Dependents  tenure  \
# 0  0002-ORFBO    No  Female              0     Yes        Yes       9
# 1  0003-MKNFE    No    Male              0      No         No       9
# 2  0004-TLHLJ   Yes    Male              0      No         No       4
# 3  0011-IGKFF   Yes    Male              1     Yes         No      13
# 4  0013-EXCHZ   Yes  Female              1     Yes         No       3
#
#   PhoneService MultipleLines InternetService  ... OnlineBackup  \
# 0          Yes            No             DSL  ...          Yes
# 1          Yes           Yes             DSL  ...           No
# 2          Yes            No     Fiber optic  ...           No
# 3          Yes            No     Fiber optic  ...          Yes
# 4          Yes            No     Fiber optic  ...           No
#
#   DeviceProtection TechSupport StreamingTV StreamingMovies        Contract  \
# 0               No         Yes         Yes              No        One year
# ...

# %%
from google.colab import files

# Supondo que df_expandido já esteja definido e processado
# Salva o DataFrame como um arquivo CSV
df_expandido.to_csv('/content/df_expandido.csv', index=False)

# Faz o download do arquivo CSV
files.download('/content/df_expandido.csv')

# %% [markdown]
# [🔝 Voltar ao Sumário](#indice)

# %% [markdown]
# <a name="etapa-7-análise-exploratória-visual-do-churn-da-telecom-x"></a>
# # 🚀 Etapa 7: Análise Exploratória Visual do Churn da Telecom X

# %% [markdown]
# 📌 O que fizemos aqui:
#
# * Filtramos só as linhas com valores válidos em Churn ('Yes' e 'No')
#
# * Criamos um gráfico interativo que mostra a quantidade de clientes que cancelaram e os que ficaram
#
# * Usamos cores diferenciadas para facilitar a visualização rápida

# %%
import plotly.express as px

def plot_churn_distribution(df, min_threshold=0.15):
    """
    Gera um gráfico de barras da distribuição de clientes que cancelaram (Churn).

    Parâmetros:
    - df (pd.DataFrame): DataFrame que contém a coluna 'Churn' com valores 'Yes' ou 'No'.
    - min_threshold (float): Valor percentual mínimo de churn (entre 0 e 1) para traçar linha de referência.

    Retorna:
    - fig (plotly.graph_objects.Figure): Figura do gráfico gerado.
    """

    # Cópia dos dados para evitar alteração do original
    df_churn = df.copy()

    # Garantir que a coluna 'Churn' contenha apenas valores válidos
    df_churn = df_churn[df_churn['Churn'].isin(['Yes', 'No'])].copy()

    # Contagem e percentual de churn
    churn_counts = df_churn['Churn'].value_counts()
    total = churn_counts.sum()
    percent_yes = (churn_counts['Yes'] / total) * 100
    percent_no = (churn_counts['No'] / total) * 100

    # Criar o gráfico
    fig = px.histogram(
        df_churn,
        x='Churn',
        color='Churn',
        title='📊 Distribuição de Cancelamento (Churn)',
        labels={'Churn': 'Cliente Cancelou?', 'count': 'Número de Clientes'},
        color_discrete_map={'Yes': 'crimson', 'No': 'mediumseagreen'},
        text_auto=True
    )

    # Adicionar linha de referência de limite mínimo de churn
    min_churn_count = total * min_threshold
    fig.add_hline(
        y=min_churn_count,
        line_dash="dash",
        line_color="red",
        annotation_text=f"Limite Mínimo de Churn: {min_threshold * 100:.0f}%",
        annotation_position="top left",
        annotation_font_color="red"
    )

    # Anotações com percentual
    fig.update_layout(
        xaxis_title='Churn (Cancelamento)',
        yaxis_title='Número de Clientes',
        showlegend=False,
        font=dict(size=14),
        annotations=[
            dict(
                x='Yes',
                y=churn_counts['Yes'],
                text=f"{percent_yes:.1f}%",
                showarrow=False,
                font=dict(color='crimson', size=16)
            ),
            dict(
                x='No',
                y=churn_counts['No'],
                text=f"{percent_no:.1f}%",
                showarrow=False,
                font=dict(color='mediumseagreen', size=16)
            )
        ]
    )

    return fig

# Gerar o gráfico de distribuição de Churn
fig_churn_distribution = plot_churn_distribution(df_expandido)

# Exibir o gráfico
fig_churn_distribution.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# [🔝 Voltar ao Sumário](#indice)

# %% [markdown]
# <a name="etapa-8-gráfico-2-distribuição-de-churn-por-tipo-de-contrato"></a>
# # 🎯 Etapa 8: Gráfico 2: Distribuição de Churn por Tipo de Contrato.

# %% [markdown]
# Esse gráfico é importante porque nos ajuda a entender qual tipo de contrato tem mais clientes cancelando. Pode indicar, por exemplo, que clientes com contratos mensais cancelam mais do que os com contratos anuais.

# %%
fig_contrato = px.histogram(
    df_expandido,
    x='Contract',
    color='Churn',
    barmode='group',
    title='🧾 Churn por Tipo de Contrato',
    labels={
        'Contract': 'Tipo de Contrato',
        'count': 'Número de Clientes',
        'Churn': 'Cancelamento (Churn)'
    },
    color_discrete_map={'Yes': 'crimson', 'No': 'mediumseagreen'}
)

fig_contrato.update_layout(
    xaxis_title='Tipo de Contrato',
    yaxis_title='Número de Clientes',
    font=dict(size=14)
)

fig_contrato.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# [🔝 Voltar ao Sumário](#indice)

# %% [markdown]
# <a name="etapa-9-gráfico-3-cancelamentos-por-método-de-pagamento"></a>
# # 📊 Etapa 9: Gráfico 3: Cancelamentos por Método de Pagamento

# %% [markdown]
# Vamos criar um histograma agrupado para visualizar a distribuição de clientes que cancelaram ou não por tipo de pagamento.

# %%
# 📊 Gráfico: Churn por Método de Pagamento
fig_pagamento = px.histogram(
    df_expandido,
    x='PaymentMethod',
    color='Churn',
    barmode='group',
    title='💳 Cancelamento por Método de Pagamento',
    labels={
        'PaymentMethod': 'Método de Pagamento',
        'count': 'Número de Clientes',
        'Churn': 'Cancelamento (Churn)'
    },
    color_discrete_map={'Yes': 'crimson', 'No': 'mediumseagreen'}
)

fig_pagamento.update_layout(
    xaxis_title='Método de Pagamento',
    yaxis_title='Número de Clientes',
    font=dict(size=14),
    xaxis_tickangle=-25
)

fig_pagamento.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# 🧠 O que observar nesse gráfico:
#
# 1. Métodos como “Electronic check” tendem a ter maior churn?
#
# 2. Há uma preferência por métodos mais tradicionais (boleto/correio)?
#
# 3. Alguma categoria se destaca por manter clientes mais fiéis?

# %% [markdown]
# [🔝 Voltar ao Sumário](#indice)

# %% [markdown]
# <a name="etapa-10-gráfico-4-cancelamentos-por-tipo-de-internet"></a>
# # 🌐 Etapa 10: Gráfico 4: Cancelamentos por Tipo de Internet

# %% [markdown]
# O serviço de internet pode impactar significativamente a experiência do cliente. Vamos explorar como o tipo de conexão (DSL, Fibra Óptica, Nenhuma) se relaciona com o churn.

# %%
# 🌐 Gráfico: Churn por Tipo de Internet
fig_internet = px.histogram(
    df_expandido,
    x='InternetService',
    color='Churn',
    barmode='group',
    title='🌐 Cancelamento por Tipo de Internet',
    labels={
        'InternetService': 'Tipo de Internet',
        'count': 'Número de Clientes',
        'Churn': 'Cancelamento (Churn)'
    },
    color_discrete_map={'Yes': 'crimson', 'No': 'mediumseagreen'}
)

fig_internet.update_layout(
    xaxis_title='Tipo de Internet',
    yaxis_title='Número de Clientes',
    font=dict(size=14)
)

fig_internet.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# 🧠 O que analisar:
#
# 1. Clientes com Fibra Óptica estão cancelando mais?
#
# 2. Quem não tem internet está menos propenso ao churn?
#
# 3. O serviço de DSL é mais estável?

# %% [markdown]
# [🔝 Voltar ao Sumário](#indice)

# %% [markdown]
# <a name="etapa-11-gráfico-churn-por-serviço-de-telefonia"></a>
# # 📞 Etapa 11: Gráfico: Churn por Serviço de Telefonia

# %% [markdown]
# Este gráfico mostra a relação entre o serviço de telefonia (PhoneService) e o cancelamento de clientes (Churn).

# %%
# 📞 Análise: Churn por Serviço de Telefonia

fig_phone = px.histogram(
    df_expandido,
    x='PhoneService',
    color='Churn',
    barmode='group',
    text_auto=True,
    title='📞 Cancelamento por Serviço de Telefonia',
    labels={'PhoneService': 'Possui Serviço Telefônico', 'Churn': 'Cancelamento'}
)

fig_phone.update_layout(
    xaxis_title='Serviço de Telefonia',
    yaxis_title='Número de Clientes',
    legend_title='Cancelamento',
    bargap=0.3,
    template='plotly_white',
    title_font_size=22
)

fig_phone.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# ##📊 Insight Esperado:
#
# A maioria dos clientes possui serviço telefônico.
#
# Comparar a taxa de churn entre quem tem e não tem serviço de telefone ajuda a entender se há relação entre esse serviço e o cancelamento.

# %% [markdown]
# [🔝 Voltar ao Sumário](#indice)

# %% [markdown]
# <a name="etapa-12-gráfico-churn-por-forma-de-pagamento"></a>
# # 💳 Etapa 12: Gráfico: Churn por Forma de Pagamento

# %% [markdown]
# Este gráfico analisa a relação entre os tipos de pagamento utilizados pelos clientes e a taxa de cancelamento.

# %%
# 💳 Análise: Churn por Forma de Pagamento
fig_pagamento = px.histogram(
    df_expandido,
    x='PaymentMethod',
    color='Churn',
    barmode='group',
    text_auto=True,
    title='💳 Cancelamento por Forma de Pagamento',
    labels={'PaymentMethod': 'Forma de Pagamento', 'Churn': 'Cancelamento'}
)

fig_pagamento.update_layout(
    xaxis_title='Forma de Pagamento',
    yaxis_title='Número de Clientes',
    legend_title='Cancelamento',
    bargap=0.3,
    template='plotly_white',
    title_font_size=22
)

fig_pagamento.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# ##📊 Insight Esperado:
#
# Clientes que usam Electronic check tendem a apresentar maior índice de churn.
#
# Pode indicar insatisfação ou vulnerabilidade entre clientes menos fidelizados (ex: pagamento eletrônico sem contrato de fidelização).

# %% [markdown]
# [🔝 Voltar ao Sumário](#indice)

# %% [markdown]
# <a name="etapa-13-gráfico-churn-por-tipo-de-internet"></a>
# # 📡 Etapa 13: Gráfico: Churn por Tipo de Internet

# %% [markdown]
# Este gráfico ajuda a identificar se o tipo de serviço de internet influencia na taxa de cancelamento.

# %%
# 📡 Análise: Churn por Tipo de Internet
fig_internet = px.histogram(
    df_expandido,
    x='InternetService',
    color='Churn',
    barmode='group',
    text_auto=True,
    title='📡 Cancelamento por Tipo de Internet',
    labels={'InternetService': 'Tipo de Internet', 'Churn': 'Cancelamento'}
)

fig_internet.update_layout(
    xaxis_title='Tipo de Internet',
    yaxis_title='Número de Clientes',
    legend_title='Cancelamento',
    bargap=0.3,
    template='plotly_white',
    title_font_size=22
)

fig_internet.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# ## 📊 Insight Esperado:
#
# * Clientes com Fiber optic tendem a ter maior churn comparado a DSL e Sem Internet.
#
# * Pode indicar insatisfação com desempenho ou custo do serviço de fibra.

# %% [markdown]
# [🔝 Voltar ao Sumário](#indice)

# %% [markdown]
# <a name="etapa-14-gráfico-distribuição-dos-valores-mensais-com-churn"></a>
# # 💰 Etapa 14: Gráfico: Distribuição dos Valores Mensais com Churn

# %% [markdown]
# Queremos ver se clientes que cancelaram pagavam valores diferentes dos que ficaram.

# %%
# 💰 Análise: Distribuição dos Valores Mensais por Churn
df_filtrado = df_expandido[df_expandido['Churn'].isin(['Yes', 'No'])]

fig_valor_mensal = px.box(
    df_filtrado,
    x='Churn',
    y='valor_mensal',
    color='Churn',
    title='💰 Distribuição do Valor Mensal por Cancelamento',
    labels={'Churn': 'Cancelamento', 'valor_mensal': 'Valor Mensal (R$)'}
)

fig_valor_mensal.update_layout(
    xaxis_title='Cancelamento',
    yaxis_title='Valor Mensal (R$)',
    showlegend=False,
    template='plotly_white',
    title_font_size=22
)

fig_valor_mensal.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# ## 📊 O que observar?
# * Clientes que cancelaram (Churn = Yes) pagam, em média, valores maiores ou menores?
#
# * Se sim, pode indicar sensibilidade ao preço ou insatisfação com custo-benefício.

# %% [markdown]
# [🔝 Voltar ao Sumário](#indice)

# %% [markdown]
# <a name="etapa-15-análise-do-tempo-de-permanência-dos-clientes-e-churn-"></a>
# # 📊 Etapa 15: Análise do Tempo de Permanência dos Clientes e Churn ⏳

# %% [markdown]
# Neste gráfico de **boxplot** com Plotly Express, comparamos o **tempo de permanência (tenure)** dos clientes que:
#
# - ❌ **cancelaram o serviço (Churn = "Yes")**
# - ✅ **continuaram (Churn = "No")**
#
# ---
#
# ### 🔍 O que observar:
#
# - 📏 A mediana (linha central da caixa) mostra o tempo típico que os clientes ficam na empresa.
# - ⏱️ Clientes que cancelaram geralmente têm menor tempo de permanência, indicando que a maior parte dos cancelamentos ocorre em clientes com menos tempo de uso.
# - 📊 A dispersão dos dados mostra a variabilidade no tempo de permanência para ambos os grupos.
# - 💡 Isso sugere que a empresa pode focar em ações para reter clientes nos primeiros meses de contrato, para reduzir o churn.
#
# ---

# %%
# Filtrando para garantir dados limpos no churn
df_plot = df_expandido[df_expandido['Churn'].isin(['Yes', 'No'])]

fig_tenure = px.box(
    df_plot,
    x='Churn',
    y='tenure',
    color='Churn',
    title='⏳ Tempo de Permanência dos Clientes por Status de Cancelamento',
    labels={
        'Churn': 'Cancelamento',
        'tenure': 'Tempo de Permanência (meses)'
    }
)

fig_tenure.update_layout(
    template='plotly_white',
    title_font_size=22,
    showlegend=False
)

fig_tenure.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# [🔝 Voltar ao Sumário](#indice)

# %% [markdown]
# <a name="etapa-16-gráfico-—-taxa-de-churn-por-tipo-de-contrato"></a>
# # 📊 Etapa 16: Gráfico — Taxa de Churn por Tipo de Contrato

# %% [markdown]
# Esse gráfico nos fornecerá uma visão de quais os possíveis contratos tem maior ou menor churn (cancelamento)

# %%
# Primeiro, calculamos a taxa de churn por tipo de contrato
taxa_churn_contrato = (
    df_expandido.groupby(['Contract', 'Churn'])
    .size()
    .reset_index(name='Quantidade')
)

# Para calcular a taxa percentual, pegamos total por contrato
total_por_contrato = taxa_churn_contrato.groupby('Contract')['Quantidade'].transform('sum')
taxa_churn_contrato['Percentual'] = taxa_churn_contrato['Quantidade'] / total_por_contrato * 100

# Ajustamos o nome dos contratos para português (opcional)
taxa_churn_contrato['Contrato'] = taxa_churn_contrato['Contract'].replace({
    'Month-to-month': 'Mensal',
    'One year': 'Anual (1 ano)',
    'Two year': 'Anual (2 anos)'
})

# Gráfico de barras empilhadas com percentual
fig_churn_contrato = px.bar(
    taxa_churn_contrato,
    x='Contrato',
    y='Percentual',
    color='Churn',
    color_discrete_map={'No': 'green', 'Yes': 'red'},
    labels={
        'Contrato': 'Tipo de Contrato',
        'Percentual': 'Percentual (%)',
        'Churn': 'Churn (Cancelamento)'
    },
    title='📉 Taxa de Churn por Tipo de Contrato na Telecom X',
    text=taxa_churn_contrato['Percentual'].apply(lambda x: f'{x:.1f}%')
)

fig_churn_contrato.update_layout(barmode='stack', yaxis=dict(ticksuffix='%'))
fig_churn_contrato.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# ### ✍️ Interpretação do Gráfico
#
# Este gráfico mostra a **taxa de churn** (cancelamento de serviço) para cada tipo de contrato dos clientes da Telecom X, agrupados em:
#
# - **Mensal** (Month-to-month)
# - **Anual (1 ano)** (One year)
# - **Anual (2 anos)** (Two year)
#
# As barras representam a proporção percentual de clientes que **não cancelaram** (em verde) e que **cancelaram** (em vermelho).
#
# **Insights importantes:**
#
# - Clientes com contrato **mensal** apresentam a **maior taxa de churn**, indicando maior propensão a cancelar.
# - Contratos de 1 ou 2 anos têm uma taxa de churn menor, sugerindo maior fidelização.
# - Recomenda-se focar estratégias para converter clientes mensais em contratos anuais para reduzir o churn.

# %% [markdown]
# [🔝 Voltar ao Sumário](#indice)

# %% [markdown]
# <a name="etapa-17-gráfico-taxa-de-churn-por-tempo-de-contrato-tenure"></a>
# # 📅 Etapa 17: Gráfico: Taxa de Churn por Tempo de Contrato (tenure)

# %%
# Criar coluna para churn numérica: 1 para 'Yes', 0 para 'No'
df_expandido['Churn_num'] = df_expandido['Churn'].map({'Yes':1, 'No':0})

# Agrupar por 'tenure' calculando taxa média de churn
churn_por_tenure = df_expandido.groupby('tenure')['Churn_num'].mean().reset_index()

# Gráfico de linha
fig_tenure = px.line(
    churn_por_tenure,
    x='tenure',
    y='Churn_num',
    labels={
        'tenure': 'Tempo de Contrato (meses)',
        'Churn_num': 'Taxa de Churn'
    },
    title='📅 Taxa de Churn por Tempo de Contrato',
    markers=True
)

fig_tenure.update_layout(yaxis_tickformat=".0%")  # Mostrar percentual no eixo y
fig_tenure.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# [🔝 Voltar ao Sumário](#indice)

# %% [markdown]
# <a name="etapa-18-um-breve-relatorio-descritivo-do-grafico-de-churn-por-tempo-de-contrato---telecom-x"></a>
#
# #📈 Etapa 18: Um breve relatório descritivo do grafico de Churn por tempo de contrato - Telecom X

# %% [markdown]
# Este gráfico mostra a taxa de churn de clientes em função do tempo de contrato (em meses).
# Observamos que a rotatividade é maior nos primeiros meses de contrato, indicando que muitos clientes cancelam cedo a relação com a Telecom X. Conforme o tempo de contrato aumenta, a taxa de churn diminui, sugerindo maior fidelização dos clientes que permanecem além do período inicial.
#
# ### Insight
# Estratégias focadas em reduzir o churn nos primeiros meses podem aumentar significativamente a retenção. Programas de boas-vindas, descontos iniciais e atendimento personalizado são exemplos de ações recomendadas.

# %% [markdown]
# [🔝 Voltar ao Sumário](#indice)

# %%
# !pip install -U plotly

# %%
# Célula 1: Instalar Kaleido
# !pip install -U kaleido

# %%
# Célula 2: Testar se Kaleido está funcionando
import plotly.io as pio

# Criar um gráfico de barras
fig = px.bar(x=["A", "B", "C"], y=[1, 3, 2])

# Salvar a imagem
pio.write_image(fig, "/content/test_kaleido.png")
print("✅ Kaleido está funcionando, imagem salva em /content/test_kaleido.png")
# Out:
# ✅ Kaleido está funcionando, imagem salva em /content/test_kaleido.png

# %%
# 🚀 Exportar gráficos como imagens PNG para /content/

# Lista de nomes das variáveis de figuras
figuras_para_salvar = [
    'fig_churn', 'fig_contrato', 'fig_pagamento', 'fig_internet',
    'fig_phone', 'fig_valor_mensal', 'fig_tenure', 'fig_churn_contrato', 'fig'
]

for nome_fig in figuras_para_salvar:
    fig = globals().get(nome_fig)
    if fig is not None:
        caminho = f"/content/{nome_fig}.png"
        fig.write_image(caminho)
        print(f"✅ {nome_fig} salva em {caminho}")
    else:
        print(f"⚠️ Figura {nome_fig} não encontrada.")
# Out:
# ⚠️ Figura fig_churn não encontrada.
# ✅ fig_contrato salva em /content/fig_contrato.png
# ✅ fig_pagamento salva em /content/fig_pagamento.png
# ✅ fig_internet salva em /content/fig_internet.png
# ✅ fig_phone salva em /content/fig_phone.png
# ✅ fig_valor_mensal salva em /content/fig_valor_mensal.png
# ✅ fig_tenure salva em /content/fig_tenure.png
# ✅ fig_churn_contrato salva em /content/fig_churn_contrato.png
# ✅ fig salva em /content/fig.png

# %% [markdown]
# <a name="etapa-19-análise-de-churn---telecom-x"></a>
# # 📈 Etapa 19: Análise de Churn - Telecom X

# %% [markdown]
# ### 🔍 Visão Geral
# - **Churn**: Proporção de clientes que cancelaram (Churn = Sim) versus os que permaneceram (Churn = Não).
# ### 📊 Análises Detalhadas
# - **Tipo de Contrato**: Clientes com contratos mensais apresentam maior índice de cancelamento.
# - **Método de Pagamento**: Clientes que utilizam pagamento eletrônico têm uma taxa de churn maior.
# - **Serviços de Internet**: Clientes com internet via fibra óptica possuem maior churn em comparação com outras tecnologias.
# - **Análise Temporal**: O churn é mais alto nos primeiros meses de permanência.
# ### 💡 Recomendações
# - **Retenção de Clientes**: Focar na retenção dos clientes com contratos mensais, oferecendo planos com benefícios para fidelização.
# - **Experiência do Cliente**: Melhorar a experiência do cliente com serviços via fibra óptica, identificando e solucionando causas de insatisfação.
# - **Políticas de Pagamento**: Revisar políticas de pagamento eletrônico, buscando incentivar métodos que gerem maior fidelidade.
# - **Suporte Proativo**: Investir em suporte e atendimento proativo nos primeiros meses de contrato, quando o churn é mais crítico.
# ---
# *Relatório gerado automaticamente por análise de dados com Python e Plotly no Colab.*

# %% [markdown]
# [🔝 Voltar ao Sumário](#indice)

# %% [markdown]
# ## ⏯ Abaixo disponibilizamos um relatório completo co as Análises realizadas

# %%
from IPython.display import display, Markdown

# Simulação do dataset para exemplo
data = {
    'Churn': ['Sim', 'Não', 'Sim', 'Não', 'Não', 'Sim', 'Não', 'Sim', 'Não', 'Não'],
    'Contrato': ['Mensal', 'Anual', 'Mensal', 'Mensal', 'Anual', 'Mensal', 'Anual', 'Mensal', 'Anual', 'Mensal'],
    'Metodo_Pagamento': ['Eletrônico', 'Boleto', 'Eletrônico', 'Cartão', 'Cartão', 'Eletrônico', 'Boleto', 'Cartão', 'Boleto', 'Eletrônico'],
    'Tecnologia_Internet': ['Fibra', 'ADSL', 'Fibra', 'Fibra', 'ADSL', 'Fibra', 'Fibra', 'ADSL', 'ADSL', 'Fibra'],
    'Tempo_Contrato': [1, 12, 3, 2, 24, 1, 18, 2, 36, 1]
}

df = pd.DataFrame(data)

# Função para exibir título + texto + gráfico
def mostrar_secao(titulo, texto, fig):
    display(Markdown(f"### {titulo}"))
    display(Markdown(texto))
    fig.show()

# Gráfico 1: Proporção Churn
fig_churn = px.pie(df, names='Churn', title='Proporção de Clientes que Cancelaram (Churn)')
mostrar_secao(
    "1. Visão Geral do Churn",
    "Neste gráfico podemos observar a proporção de clientes que cancelaram (Churn = Sim) versus os que permaneceram (Churn = Não).",
    fig_churn
)

# Gráfico 2: Churn por Tipo de Contrato
contrato_churn = df.groupby(['Contrato', 'Churn']).size().reset_index(name='count')
fig_contrato = px.bar(contrato_churn, x='Contrato', y='count', color='Churn', barmode='group',
                     title='Churn por Tipo de Contrato')
mostrar_secao(
    "2. Análise por Tipo de Contrato",
    "A análise mostra a relação entre o tipo de contrato e a taxa de churn. Clientes com contratos mensais apresentam maior índice de cancelamento.",
    fig_contrato
)

# Gráfico 3: Churn por Método de Pagamento
pagamento_churn = df.groupby(['Metodo_Pagamento', 'Churn']).size().reset_index(name='count')
fig_pagamento = px.bar(pagamento_churn, x='Metodo_Pagamento', y='count', color='Churn', barmode='group',
                      title='Churn por Método de Pagamento')
mostrar_secao(
    "3. Análise por Método de Pagamento",
    "Observa-se que clientes que utilizam pagamento eletrônico têm uma taxa de churn maior comparada aos demais métodos.",
    fig_pagamento
)

# Gráfico 4: Churn por Tecnologia de Internet
internet_churn = df.groupby(['Tecnologia_Internet', 'Churn']).size().reset_index(name='count')
fig_internet = px.bar(internet_churn, x='Tecnologia_Internet', y='count', color='Churn', barmode='group',
                    title='Churn por Tecnologia de Internet')
mostrar_secao(
    "4. Serviços de Internet e Churn",
    "O gráfico indica que clientes com internet via fibra óptica possuem maior churn em comparação com outras tecnologias.",
    fig_internet
)

# Gráfico 5: Churn por Tempo de Contrato (mês)
tempo_churn = df.groupby(['Tempo_Contrato', 'Churn']).size().reset_index(name='count')
fig_tempo = px.bar(tempo_churn, x='Tempo_Contrato', y='count', color='Churn', barmode='group',
                   title='Análise Temporal do Churn por Tempo de Contrato')
mostrar_secao(
    "5. Análise Temporal do Churn por Tempo de Contrato",
    "Este gráfico mostra a evolução da taxa de churn em função do tempo de permanência. O churn é mais alto nos primeiros meses.",
    fig_tempo
)

# Recomendações finais
display(Markdown("""
---
## 🔍 Recomendações para a Telecom X

- **Focar na retenção dos clientes com contratos mensais**, oferecendo planos com benefícios para fidelização.
- **Melhorar a experiência do cliente com serviços via fibra óptica**, identificando e solucionando causas de insatisfação.
- **Revisar políticas de pagamento eletrônico**, buscando incentivar métodos que gerem maior fidelidade.
- **Investir em suporte e atendimento proativo nos primeiros meses de contrato**, quando o churn é mais crítico.

---

Este relatório oferece um panorama claro e visual para tomadas de decisão estratégicas visando reduzir o churn e aumentar a fidelização de clientes.

*Relatório gerado automaticamente por análise de dados com Python e Plotly no Colab.*
"""))
# Out:
# ### 1. Visão Geral do Churn
# Neste gráfico podemos observar a proporção de clientes que cancelaram (Churn = Sim) versus os que permaneceram (Churn = Não).
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# ## 📄 Classe Personalizada para Formatação de PDF
#
# ### 🛠️ O Código abaixo gera uma Classe Personalizada
# Este código implementa uma classe que permite a formatação de documentos PDF e a exibição de relatórios de forma eficiente e estilizada.
#
# - **📜 Funcionalidades**:
#   - Geração de relatórios em PDF com formatação customizada.
#   - Inclusão de gráficos e tabelas diretamente no documento.
#   - Opções de personalização para cabeçalhos, rodapés e estilos.
#
# ### 📊 Exibição do Relatório
# A classe também facilita a visualização do relatório gerado, permitindo que os usuários acessem as informações de maneira clara e organizada.
#
# ---
#
# *Relatório gerado automaticamente por análise de dados com Python.*

# %%
# !pip install fpdf
# Out:
# ...
#   Preparing metadata (setup.py) ... done
# ...
#   Created wheel for fpdf: filename=fpdf-1.7.2-py2.py3-none-any.whl size=40704 sha256=c5fd180793faef0d9435ee225aa31c7a5229a80b0a3b9cfa80b8803e3c836e8b
#   Stored in directory: /root/.cache/pip/wheels/65/4f/66/bbda9866da446a72e206d6484cd97381cbc7859a7068541c36
# Successfully built fpdf
# ...

# %%
from fpdf import FPDF

# Classe personalizada para formatação do PDF
class PDF(FPDF):
    def header(self):
        self.set_font("Arial", "B", 14)
        self.cell(0, 10, "Relatório de Análise de Churn - Telecom X", ln=True, align="C")
        self.ln(10)

    def chapter_title(self, title):
        self.set_font("Arial", "B", 12)
        self.set_text_color(0)
        self.cell(0, 10, title, ln=True)
        self.ln(4)

    def chapter_body(self, body):
        self.set_font("Arial", "", 11)
        self.multi_cell(0, 8, body)
        self.ln()

# Criar o PDF
pdf = PDF()
pdf.add_page()

# Recomendação final
recomendacoes = """
Recomendações para a Telecom X:

- Focar na retenção dos clientes com contratos mensais, oferecendo planos com benefícios para fidelização.
- Melhorar a experiência do cliente com serviços via fibra óptica, identificando e solucionando causas de insatisfação.
- Revisar políticas de pagamento eletrônico, buscando incentivar métodos que gerem maior fidelidade.
- Investir em suporte e atendimento proativo nos primeiros meses de contrato, quando o churn é mais crítico.

Este relatório oferece um panorama claro e visual para tomadas de decisão estratégicas visando reduzir o churn e aumentar a fidelização de clientes.

Relatório gerado automaticamente por análise de dados com Python e Plotly no Colab.
"""

# Adicionando o conteúdo
pdf.chapter_title("Recomendações Finais")
pdf.chapter_body(recomendacoes)

# Exportando o PDF
pdf_path = "/content/relatorio_churn_telecomx.pdf"
pdf.output(pdf_path)

print(f"✅ PDF gerado com sucesso: {pdf_path}")
# Out:
# ✅ PDF gerado com sucesso: /content/relatorio_churn_telecomx.pdf

# %% [markdown]
# [🔝 Voltar ao Sumário](#indice)

# %% [markdown]
# <a name="etapa-20-download-do-relatório"></a>
# # 📥 Etapa 20: Download do Relatório

# %% [markdown]
# Clique no link abaixo para baixar o relatório final de churn da Telecom X em formato PDF, contendo análises visuais e recomendações estratégicas geradas com Python.

# %%
from IPython.display import FileLink

# 🔗 Link para download do PDF gerado
FileLink('/content/relatorio_churn_telecomx.pdf')
# Out:
# /content/relatorio_churn_telecomx.pdf

# %% [markdown]
# [🔝 Voltar ao Sumário](#indice)

# %% [markdown]
# <a name="etapa-21-próximo-passo-pré-processamento-para-machine-learning"></a>
# ## 🔜 Etapa 21: Próximo Passo: Pré-processamento para Machine Learning

# %% [markdown]
# ✅ Etapas:
# Separar variáveis preditoras (X) e alvo (y)
#
# * Codificar variáveis categóricas com OneHotEncoder
#
# * Dividir em treino e teste
#
# * Treinar modelo Random Forest
#
# * Avaliar desempenho com métricas
#
# * Exibir importância das variáveis

# %% [markdown]
# ## 🔜 Pré-processamento para Machine Learning com Random Forest
#
# Nesta etapa, vamos preparar os dados para aplicar um modelo de Machine Learning do tipo Random Forest.
#
# O objetivo é prever o churn (cancelamento) dos clientes com base nas características presentes no nosso dataset `df_expandido`.
#
# ### O que faremos:
# - Criar uma coluna numérica para a variável target (`Churn`).
# - Tratar valores ausentes.
# - Codificar variáveis categóricas.
# - Separar os dados em conjuntos de treino e teste.
# - Treinar o modelo Random Forest.
# - Avaliar o desempenho do modelo.

# %% [markdown]
# ## 🔜 Próximo Passo: Pré-processamento e Treinamento do Modelo Random Forest
#
# Nesta etapa, preparamos os dados para o modelo de Machine Learning e treinamos um classificador Random Forest para prever o churn dos clientes.
#
# ### Passos realizados:
#
# 1. **Criação da variável alvo numérica (`Churn_num`):**
#    Convertendo a variável categórica `Churn` em valores binários, onde 'No' vira 0 e 'Yes' vira 1, facilitando o trabalho do algoritmo.
#
# 2. **Tratamento de dados faltantes:**
#    Removemos registros que possuem valores nulos nas colunas críticas, como `valor_total` e `Churn_num`, para garantir que o modelo receba dados limpos.
#
# 3. **Separação entre variáveis explicativas (features) e alvo (target):**
#    Removemos colunas irrelevantes para o modelo, como `id_cliente` e a coluna original `Churn`.
#
# 4. **Codificação das variáveis categóricas:**
#    Utilizamos `LabelEncoder` para transformar variáveis textuais em números, permitindo que o modelo processe essas informações.
#
# 5. **Divisão dos dados em treino e teste:**
#    Reservamos 20% dos dados para teste, garantindo a validação do modelo em dados nunca vistos.
#
# 6. **Treinamento do Random Forest:**
#    Aplicamos o algoritmo Random Forest, um ensemble robusto e eficiente para classificação, para aprender padrões que indicam o churn.
#
# 7. **Avaliação do modelo:**
#    Calculamos métricas de desempenho como acurácia, matriz de confusão e relatório detalhado, para entender a eficácia da predição.
#
# ---
#
# Este processo prepara o caminho para análises preditivas e para entender melhor o comportamento dos clientes que cancelam serviços, auxiliando a empresa a tomar decisões estratégicas para retenção.

# %%
# Verificando a quantidade total de NaNs no dataframe
total_nans = df_expandido.isna().sum().sum()
print(f"Total de valores NaN no dataframe: {total_nans}")

# Mostrar NaNs por coluna para um diagnóstico mais detalhado
print("\nQuantidade de NaNs por coluna:")
print(df_expandido.isna().sum())
# Out:
# Total de valores NaN no dataframe: 224
#
# Quantidade de NaNs por coluna:
# id_cliente            0
# Churn                 0
# gender                0
# SeniorCitizen         0
# Partner               0
# Dependents            0
# tenure                0
# PhoneService          0
# MultipleLines         0
# InternetService       0
# OnlineSecurity        0
# OnlineBackup          0
# DeviceProtection      0
# TechSupport           0
# StreamingTV           0
# StreamingMovies       0
# Contract              0
# PaperlessBilling      0
# PaymentMethod         0
# valor_mensal          0
# valor_total           0
# Churn_num           224
# dtype: int64

# %% [markdown]
# [🔝 Voltar ao Sumário](#indice)

# %% [markdown]
# <a name="etapa-22-modelo-de-classificação-com-random-forest-e-balanceamento-de-classes-usando-smote"></a>
# ## 🎯 Etapa 22: Modelo de Classificação com Random Forest e Balanceamento de Classes usando SMOTE

# %% [markdown]
# Neste notebook, vamos construir um modelo preditivo para identificar clientes que irão cancelar um serviço (churn) utilizando Random Forest. O processo inclui as seguintes etapas principais:
#
# 1. **Preparação dos Dados**
#    - Separação das variáveis independentes (`features`) e da variável alvo (`target`), que indica se o cliente deu churn ou não.
#    - Identificação das colunas numéricas e categóricas para aplicar o pré-processamento adequado.
#
# 2. **Pré-processamento**
#    - Aplicação de One-Hot Encoding para transformar as variáveis categóricas em um formato numérico adequado para o modelo.
#    - Manutenção das variáveis numéricas originais.
#
# 3. **Divisão Treino/Teste**
#    - Dividimos os dados em conjuntos de treino e teste, preservando a proporção da variável alvo (`stratify=y`) para garantir representatividade.
#
# 4. **Balanceamento com SMOTE**
#    - O conjunto de treino é balanceado utilizando o SMOTE, técnica que gera amostras sintéticas para a classe minoritária, prevenindo viés do modelo.
#
# 5. **Treinamento e Otimização do Modelo**
#    - Treinamos um classificador Random Forest.
#    - Utilizamos `GridSearchCV` para encontrar os melhores hiperparâmetros do modelo, avaliando por meio de validação cruzada (5 folds) e otimizando a métrica F1-score.
#
# 6. **Avaliação Final**
#    - O modelo otimizado é avaliado no conjunto de teste.
#    - São calculadas as métricas de acurácia, precisão, recall, F1-score, além da matriz de confusão para análise detalhada do desempenho.
#
# Esta abordagem é robusta para lidar com dados desbalanceados e combina pré-processamento cuidadoso com tuning automático de hiperparâmetros para alcançar alta performance na tarefa de classificação.
#
# ---

# %%
from sklearn.model_selection import train_test_split, GridSearchCV
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import classification_report, confusion_matrix, accuracy_score
from imblearn.over_sampling import SMOTE
from sklearn.preprocessing import OneHotEncoder
from sklearn.compose import ColumnTransformer
import joblib

# Carregar os dados do arquivo CSV
df = pd.read_csv('/content/df_expandido.csv')

# Nome da coluna target
target = 'Churn'

# Ver valores únicos da coluna target
print("Valores únicos em Churn:", df[target].unique())

# Mapear valores texto para 0 e 1
map_churn = {'No': 0, 'Yes': 1}
df[target] = df[target].map(map_churn)

# Remover linhas com target nulo
df = df.dropna(subset=[target])

# Garantir que o target seja int
y = df[target].astype(int)

# Definir features
features = df.drop(columns=[target]).columns.tolist()
X = df[features]

# Separar variáveis numéricas e categóricas
num_features = X.select_dtypes(include=['int64', 'float64']).columns.tolist()
cat_features = X.select_dtypes(include=['object', 'bool']).columns.tolist()

# Pipeline de pré-processamento
preprocessor = ColumnTransformer(
    transformers=[
        ('cat', OneHotEncoder(handle_unknown='ignore'), cat_features)
    ],
    remainder='passthrough'
)

# Separar dados treino e teste
X_train, X_test, y_train, y_test = train_test_split(
    X, y, test_size=0.3, random_state=42, stratify=y
)

# Aplicar pré-processamento
X_train_prep = preprocessor.fit_transform(X_train)
X_test_prep = preprocessor.transform(X_test)

# Aplicar SMOTE para balancear as classes
smote = SMOTE(random_state=42)
X_train_smote, y_train_smote = smote.fit_resample(X_train_prep, y_train)

# Configurar Random Forest
rf = RandomForestClassifier(random_state=42)

# Parâmetros para GridSearch
param_grid = {
    'n_estimators': [100, 200],
    'max_depth': [10, 20, None],
    'min_samples_split': [2, 5]
}

# GridSearch com 5 folds e métrica F1
grid_search = GridSearchCV(rf, param_grid, cv=5, scoring='f1', n_jobs=-1)

# Treinar o modelo com dados balanceados
grid_search.fit(X_train_smote, y_train_smote)

print("Melhores parâmetros encontrados:", grid_search.best_params_)

# Avaliar no conjunto de teste
y_pred = grid_search.predict(X_test_prep)

print("Acurácia:", accuracy_score(y_test, y_pred))
print("\nRelatório de Classificação:\n", classification_report(y_test, y_pred))
print("Matriz de Confusão:\n", confusion_matrix(y_test, y_pred))

# --------- SALVAR MODELO E PREPROCESSOR ---------

# Melhor modelo treinado
modelo_rf = grid_search.best_estimator_

# Salvar modelo e pré-processador
joblib.dump(modelo_rf, 'modelo_rf.joblib')
joblib.dump(preprocessor, 'preprocessor.joblib')

print("Arquivos modelo_rf.joblib e preprocessor.joblib salvos com sucesso!")

# --- Download direto no Colab ---
try:
    from google.colab import files
    files.download('modelo_rf.joblib')
    files.download('preprocessor.joblib')
except ImportError:
    print("Não está rodando no Colab, pule o download automático.")
# Out:
# Valores únicos em Churn: ['No' 'Yes' nan]
# Melhores parâmetros encontrados: {'max_depth': 20, 'min_samples_split': 2, 'n_estimators': 100}
# Acurácia: 0.77520113582584
#
# Relatório de Classificação:
#                precision    recall  f1-score   support
#
#            0       0.86      0.83      0.84      1552
#            1       0.57      0.63      0.60       561
#
#     accuracy                           0.78      2113
#    macro avg       0.72      0.73      0.72      2113
# weighted avg       0.78      0.78      0.78      2113
#
# Matriz de Confusão:
#  [[1282  270]
#  [ 205  356]]
# Arquivos modelo_rf.joblib e preprocessor.joblib salvos com sucesso!

# %% [markdown]
# [🔝 Voltar ao Sumário](#indice)

# %% [markdown]
# <a name="etapa-23-análise-da-importância-das-features-no-modelo-random-forest"></a>
# ## 📊 Etapa 23: Análise da Importância das Features no Modelo Random Forest

# %% [markdown]
# Nesta etapa, avaliamos quais variáveis tiveram maior impacto na capacidade preditiva do melhor modelo Random Forest obtido pelo `GridSearchCV`.
#
# ---
#
# ## 1. Extração da Importância das Features
#
# O atributo `feature_importances_` do modelo retorna um score numérico para cada variável, indicando sua relevância na construção das árvores e, consequentemente, na tomada de decisão do modelo.
#
# ---
#
# ## 2. Recuperação dos Nomes das Features Pós-Pré-processamento
#
# Como o conjunto de dados passou por transformações — principalmente o `OneHotEncoder` aplicado às variáveis categóricas — precisamos:
#
# - Obter os nomes das categorias expandidas pelo encoder;
# - Combinar esses nomes com as features numéricas que foram mantidas sem alteração.
#
# Isso garante uma correspondência correta entre nomes e scores de importância.
#
# ---
#
# ## 3. Organização dos Dados para Visualização
#
# Criamos um DataFrame ordenado em ordem decrescente de importância, facilitando a identificação das variáveis mais relevantes para o modelo.
#
# ---
#
# ## 4. Visualização Gráfica
#
# Apresentamos um gráfico de barras horizontais com as **10 features mais importantes**, que destaca visualmente os principais fatores que influenciam a predição do churn.
#
# ---
#
# ### Importância da Análise
#
# Compreender as features mais relevantes é fundamental para:
#
# - Interpretar o comportamento do modelo;
# - Identificar variáveis-chave para decisões estratégicas e intervenções;
# - Guiar ações focadas em reduzir o churn com base em dados concretos.
#
# ---
#
# > **Nota:** Esta análise complementa a avaliação quantitativa do modelo, permitindo uma visão qualitativa que agrega valor à interpretação dos resultados.

# %%
import numpy as np
import matplotlib.pyplot as plt

# Objeto do melhor modelo treinado
modelo_rf = grid_search.best_estimator_

# 1. Importância das features
importancias = modelo_rf.feature_importances_

# 2. Pegando os nomes das colunas após o pré-processamento (OneHotEncoder + passthrough)
# Isso é um pouco complexo, pois preprocessor é um ColumnTransformer

# Extrair os nomes das features do OneHotEncoder
ohe = preprocessor.named_transformers_['cat']
nomes_cat = ohe.get_feature_names_out(cat_features)

# Combinar nomes das colunas transformadas
nomes_features = np.concatenate([nomes_cat, num_features])

# 3. Criar DataFrame para visualização
df_importancias = pd.DataFrame({
    'feature': nomes_features,
    'importance': importancias
}).sort_values(by='importance', ascending=False)

print(df_importancias)

# 4. Plotar gráfico das 10 features mais importantes
plt.figure(figsize=(10,6))
plt.barh(df_importancias['feature'].head(10)[::-1], df_importancias['importance'].head(10)[::-1])
plt.xlabel('Importância')
plt.title('Top 10 Features mais importantes no Random Forest')
plt.show()
# Out:
#                              feature  importance
# 4962         Contract_Month-to-month    0.083702
# 4972                          tenure    0.048764
# 4953                  TechSupport_No    0.048377
# 4969  PaymentMethod_Electronic check    0.045336
# 4947                 OnlineBackup_No    0.040490
# ...                              ...         ...
# 53             id_cliente_0136-IFMYD    0.000000
# 1600           id_cliente_3244-DCJWY    0.000000
# 47             id_cliente_0123-CRBRT    0.000000
# 3090           id_cliente_6217-KDYWC    0.000000
# 4898           id_cliente_9932-WBWIK    0.000000
#
# [4975 rows x 2 columns]

# %% [markdown]
# [🔝 Voltar ao Sumário](#indice)

# %% [markdown]
# <a name="etapa-24-treinamento-e-avaliação-do-modelo-random-forest-com-as-10-features-mais-importantes"></a>
# ## 🎯 Etapa 24: Treinamento e Avaliação do Modelo Random Forest com as 10 Features Mais Importantes

# %% [markdown]
# Neste bloco, realizamos uma nova rodada de treinamento e avaliação utilizando **apenas as 10 variáveis mais relevantes** identificadas na etapa anterior de análise de importância das features. O objetivo é verificar se o modelo mantém boa performance com um conjunto reduzido de dados, o que pode trazer benefícios como:
#
# - Redução de complexidade computacional;
# - Melhor interpretabilidade;
# - Potencial melhoria na generalização do modelo.
#
# ---
#
# ## Etapas detalhadas:
#
# ### 1. Extração das Features Mais Importantes
#
# - Utilizamos o atributo `feature_importances_` do melhor modelo Random Forest previamente treinado para obter o ranking das variáveis.
# - Recuperamos os nomes das features já transformadas pelo pipeline de pré-processamento (`OneHotEncoder` + demais transformações).
#
# ### 2. Seleção das Top 10 Features
#
# - Construímos um DataFrame ordenado pela importância e extraímos as 10 principais variáveis.
# - Mapeamos os índices dessas variáveis para seleção nas matrizes pré-processadas de treino e teste.
#
# ### 3. Pré-processamento com Features Selecionadas
#
# - Aplicamos o pré-processamento (`transform`) aos dados originais para obter as matrizes numéricas completas.
# - Selecionamos apenas as colunas correspondentes às 10 features mais importantes.
#
# ### 4. Balanceamento dos Dados com SMOTE
#
# - Aplicamos o SMOTE apenas no conjunto de treino com as features reduzidas para corrigir o desbalanceamento da classe alvo.
#
# ### 5. Treinamento do Modelo Reduzido
#
# - Treinamos um novo modelo Random Forest com os melhores parâmetros encontrados no `GridSearchCV`, mas utilizando apenas as features selecionadas.
#
# ### 6. Avaliação do Modelo
#
# - Avaliamos a acurácia, além do relatório de classificação e matriz de confusão, para medir o desempenho da versão reduzida do modelo no conjunto de teste.
#
# ---
#
# ## Importância desta abordagem
#
# Reduzir o número de features sem perder performance é uma prática recomendada para:
#
# - Tornar modelos mais eficientes e rápidos;
# - Facilitar a interpretação e comunicação dos resultados para stakeholders;
# - Minimizar possíveis ruídos causados por variáveis irrelevantes.
#
# ---
#
# > **Dica:** Sempre valide o desempenho do modelo com features reduzidas para garantir que a simplificação não prejudique a qualidade da predição.

# %%
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import classification_report, confusion_matrix, accuracy_score
from imblearn.over_sampling import SMOTE
from sklearn.preprocessing import OneHotEncoder
from sklearn.compose import ColumnTransformer

# --- Supondo que você já tenha esses objetos após seu treinamento inicial ---
# grid_search: GridSearchCV com RandomForest já treinado
# preprocessor: ColumnTransformer com OneHotEncoder já fitado
# X_train, X_test, y_train, y_test: já definidos

# 1. Extrair importâncias do melhor modelo
modelo_rf = grid_search.best_estimator_
importancias = modelo_rf.feature_importances_

# 2. Pegar nomes das features após o preprocessor (OneHotEncoder)
nomes_features = preprocessor.get_feature_names_out()

# 3. Criar DataFrame para visualizar importâncias
df_importancia = pd.DataFrame({
    'feature': nomes_features,
    'importance': importancias
}).sort_values(by='importance', ascending=False)

print("Top 10 features mais importantes:")
print(df_importancia.head(10))

top_features = df_importancia['feature'].head(10).tolist()

# 4. Mapear índices das colunas que correspondem às top features
indices_top_features = [i for i, f in enumerate(nomes_features) if f in top_features]

# 5. Selecionar colunas top features do treino e teste pré-processados
X_train_prep = preprocessor.transform(X_train)  # certifique-se que X_train e X_test são os originais antes do fit_transform
X_test_prep = preprocessor.transform(X_test)

X_train_top = X_train_prep[:, indices_top_features]
X_test_top = X_test_prep[:, indices_top_features]

# 6. Aplicar SMOTE somente no treino com features selecionadas
smote = SMOTE(random_state=42)
X_train_smote_top, y_train_smote_top = smote.fit_resample(X_train_top, y_train)

# 7. Treinar Random Forest com melhores parâmetros no conjunto reduzido
rf_top = RandomForestClassifier(
    n_estimators=grid_search.best_params_['n_estimators'],
    max_depth=grid_search.best_params_['max_depth'],
    min_samples_split=grid_search.best_params_['min_samples_split'],
    random_state=42
)

rf_top.fit(X_train_smote_top, y_train_smote_top)

# 8. Avaliar modelo no teste
y_pred_top = rf_top.predict(X_test_top)

print("Acurácia com top 10 features:", accuracy_score(y_test, y_pred_top))
print("\nRelatório de Classificação com top 10 features:\n", classification_report(y_test, y_pred_top))
print("Matriz de Confusão com top 10 features:\n", confusion_matrix(y_test, y_pred_top))
# Out:
# Top 10 features mais importantes:
#                                   feature  importance
# 4962         cat__Contract_Month-to-month    0.083702
# 4972                    remainder__tenure    0.048764
# 4953                  cat__TechSupport_No    0.048377
# 4969  cat__PaymentMethod_Electronic check    0.045336
# 4947                 cat__OnlineBackup_No    0.040490
# 4974               remainder__valor_total    0.038331
# 4942     cat__InternetService_Fiber optic    0.030703
# 4964               cat__Contract_Two year    0.030037
# 4946              cat__OnlineSecurity_Yes    0.028071
# 4955                 cat__TechSupport_Yes    0.026928
# Acurácia com top 10 features: 0.7718883104590629
#
# Relatório de Classificação com top 10 features:
#                precision    recall  f1-score   support
#
#            0       0.84      0.85      0.85      1552
#            1       0.57      0.56      0.56       561
#
#     accuracy                           0.77      2113
# ...

# %% [markdown]
# [🔝 Voltar ao Sumário](#indice)

# %% [markdown]
# <a name="etapa-25-avaliação-do-modelo-com-ajuste-de-threshold-e-curvas-roc--precision-recall"></a>
# ## 📊 Etapa 25: Avaliação do Modelo com Ajuste de Threshold e Curvas ROC / Precision-Recall

# %% [markdown]
# Neste trecho de código, aprofundamos a avaliação do modelo de classificação balanceado pelo SMOTE e otimizado via Random Forest, focando em:
#
# - **Análise das probabilidades preditas** para a classe positiva;
# - **Visualização das curvas ROC e Precision-Recall**, métricas essenciais para avaliar classificadores binários, especialmente em datasets desbalanceados;
# - **Ajuste do threshold de decisão** para encontrar o ponto ótimo que balanceia recall e precisão, indo além do valor padrão (0.5).
#
# ---
#
# ## Passos realizados:
#
# ### 1. Cálculo das probabilidades preditas
#
# - Extraímos as probabilidades previstas para a classe positiva (`y_prob`) usando o método `predict_proba` do melhor modelo encontrado (`grid_search`).
#
# ### 2. Função para avaliação do modelo em diferentes thresholds
#
# - Criamos uma função que, dado um valor de threshold, converte probabilidades em predições binárias, calcula e imprime:
#   - Relatório de classificação detalhado (precisão, recall, F1-score);
#   - Matriz de confusão;
#   - Acurácia.
#
# ### 3. Plotagem das curvas ROC e Precision-Recall
#
# - **Curva ROC:** mostra a relação entre taxa de falso positivo (FPR) e verdadeiro positivo (TPR) para vários thresholds.
# - **Curva Precision-Recall:** essencial para avaliar modelos em cenários desbalanceados, destacando o trade-off entre precisão e recall.
# - Calculamos e exibimos as métricas AUC-ROC e Average Precision (AP).
#
# ### 4. Teste prático de diferentes thresholds
#
# - Avaliamos o desempenho do modelo para thresholds variados (0.3, 0.4, 0.5, 0.6, 0.7).
# - Essa análise permite escolher o threshold que melhor se adequa aos objetivos do negócio, como priorizar menor taxa de falsos negativos (recall) ou maior precisão.
#
# ### 5. Avaliação final com threshold ajustado
#
# - Aplicamos o threshold escolhido (exemplo: 0.4) para obter a predição final e avaliamos o desempenho correspondente.
#
# ---
#
# ## Importância do ajuste de threshold
#
# - O threshold padrão de 0.5 pode não ser ideal, especialmente em casos de classes desbalanceadas.
# - Ajustar o threshold pode melhorar significativamente o desempenho do modelo para objetivos específicos, como minimizar falsos negativos em problemas críticos (ex.: churn, fraude, doenças).
# - As curvas e métricas auxiliam na escolha informada do threshold mais adequado.
#
# ---
#
# > **Recomendação:** Sempre combine análise quantitativa com conhecimento do negócio para definir o threshold ótimo.

# %%
from sklearn.metrics import (
    roc_auc_score, roc_curve,
    precision_recall_curve, average_precision_score,
    classification_report, confusion_matrix
)

# Supondo que você já tem o grid_search treinado e X_test_prep, y_test definidos

# 1. Obter probabilidades preditas para a classe positiva
y_prob = grid_search.predict_proba(X_test_prep)[:, 1]

# 2. Definir função para avaliar o modelo para diferentes thresholds
def avaliar_threshold(threshold, y_prob, y_true):
    y_pred = (y_prob >= threshold).astype(int)
    print(f"\n=== Avaliação para threshold = {threshold:.2f} ===")
    print("Relatório de Classificação:")
    print(classification_report(y_true, y_pred))
    print("Matriz de Confusão:")
    print(confusion_matrix(y_true, y_pred))
    acc = (y_pred == y_true).mean()
    print(f"Acurácia: {acc:.4f}")
    return y_pred

# 3. Plotar curva ROC e Precision-Recall
fpr, tpr, thresholds_roc = roc_curve(y_test, y_prob)
precision, recall, thresholds_pr = precision_recall_curve(y_test, y_prob)
auc_roc = roc_auc_score(y_test, y_prob)
ap_score = average_precision_score(y_test, y_prob)

plt.figure(figsize=(12,5))

plt.subplot(1,2,1)
plt.plot(fpr, tpr, label=f'AUC-ROC = {auc_roc:.2f}')
plt.plot([0,1],[0,1],'k--')
plt.xlabel('Falso Positivo')
plt.ylabel('Verdadeiro Positivo')
plt.title('Curva ROC')
plt.legend()

plt.subplot(1,2,2)
plt.plot(recall, precision, label=f'AP = {ap_score:.2f}')
plt.xlabel('Recall')
plt.ylabel('Precision')
plt.title('Curva Precision-Recall')
plt.legend()

plt.tight_layout()
plt.show()

# 4. Testar diferentes thresholds para achar um bom ponto de corte
thresholds_teste = [0.3, 0.4, 0.5, 0.6, 0.7]
for th in thresholds_teste:
    avaliar_threshold(th, y_prob, y_test)

# Você pode escolher o threshold que melhor balanceia recall e precision para seu objetivo
# Por exemplo, suponha que 0.4 é um bom valor:
threshold_escolhido = 0.4
y_pred_ajustado = (y_prob >= threshold_escolhido).astype(int)

print(f"\n=== Avaliação final com threshold ajustado = {threshold_escolhido} ===")
print(classification_report(y_test, y_pred_ajustado))
print("Matriz de Confusão:")
print(confusion_matrix(y_test, y_pred_ajustado))
# Out:
# === Avaliação para threshold = 0.30 ===
# Relatório de Classificação:
#               precision    recall  f1-score   support
#
#            0       0.93      0.65      0.76      1552
#            1       0.47      0.86      0.61       561
#
#     accuracy                           0.71      2113
#    macro avg       0.70      0.76      0.69      2113
# weighted avg       0.81      0.71      0.72      2113
#
# Matriz de Confusão:
# [[1008  544]
#  [  77  484]]
# Acurácia: 0.7061
#
# === Avaliação para threshold = 0.40 ===
# Relatório de Classificação:
#               precision    recall  f1-score   support
#
#            0       0.90      0.75      0.82      1552
#            1       0.53      0.78      0.63       561
#
#     accuracy                           0.75      2113
#    macro avg       0.71      0.76      0.72      2113
# weighted avg       0.80      0.75      0.77      2113
#
# Matriz de Confusão:
# [[1160  392]
#  [ 126  435]]
# Acurácia: 0.7549
#
# ...

# %% [markdown]
# [🔝 Voltar ao Sumário](#indice)

# %% [markdown]
# <a name="etapa-26-resumo-do-que-o-código-acima-faz"></a>
# ## ✅ Etapa 26: Resumo do Que o Código acima Faz

# %% [markdown]
# | Etapa | Descrição |
# |-------|----------|
# | 1 | Extrai as **importâncias** das features do melhor modelo (`grid_search.best_estimator_`) |
# | 2 | Usa o `ColumnTransformer` para recuperar os **nomes das variáveis já transformadas** |
# | 3 | Cria um DataFrame `df_importancia` com os nomes e importâncias |
# | 4 | Seleciona os **10 atributos mais importantes** |
# | 5 | Extrai essas colunas do conjunto transformado de treino/teste |
# | 6 | Aplica **SMOTE** apenas no treino com essas 10 colunas |
# | 7 | Treina um novo **Random Forest** com os **melhores hiperparâmetros** já encontrados |
# | 8 | Avalia a performance no conjunto de teste |

# %% [markdown]
# [🔝 Voltar ao Sumário](#indice)

# %% [markdown]
# <a name="etapa-27-função-para-avaliação-do-modelo-com-threshold-personalizado"></a>
# ## 🚦 Etapa 27: Função para Avaliação do Modelo com Threshold Personalizado

# %% [markdown]
# Esta função facilita a avaliação de modelos de classificação binária ajustando o threshold de decisão para gerar predições e calcular métricas de desempenho.
#
# ---
#
# ## Descrição da função `avaliar_threshold`
#
# ```python
# def avaliar_threshold(modelo, X_teste, y_teste, threshold=0.5):
#     # 1. Obtenção das probabilidades previstas para a classe positiva
#     probs = modelo.predict_proba(X_teste)[:, 1]
#
#     # 2. Aplicação do threshold customizado para gerar as predições binárias
#     preds = (probs >= threshold).astype(int)
#
#     # 3. Impressão das métricas de avaliação
#     print(f"=== Avaliação para threshold = {threshold:.2f} ===")
#     print("Relatório de Classificação:")
#     print(classification_report(y_teste, preds))
#     print("Matriz de Confusão:")
#     print(confusion_matrix(y_teste, preds))
#     print("Acurácia:", accuracy_score(y_teste, preds))
#     print("\n")
#
#     # 4. Retorno das predições binárias geradas
#     return preds

# %% [markdown]
# [🔝 Voltar ao Sumário](#indice)

# %% [markdown]
# <a name="etapa-28-predição-e-avaliação-com-threshold-customizado-e-salvamento-em-csv"></a>
# ## 📈 Etapa 28: Predição e Avaliação com Threshold Customizado e Salvamento em CSV

# %% [markdown]
# Este conjunto de funções permite realizar predições usando um threshold customizado para converter probabilidades em classes binárias, avaliar as predições e, opcionalmente, salvar os resultados em arquivo CSV para posterior análise.
#
# ---
#
# ## Função `predizer_com_threshold`
#
# ### Descrição
# Realiza a predição de classes com um limiar (threshold) ajustável, retornando as predições binárias e as probabilidades previstas. Também oferece a opção de salvar as predições e probabilidades em um arquivo CSV.
#
# ### Parâmetros
# - `modelo`: modelo treinado que implementa o método `predict_proba`.
# - `X`: conjunto de features pré-processadas para predição.
# - `threshold` (float, padrão=0.5): valor limite para converter probabilidades em classes binárias.
# - `salvar_csv` (bool, padrão=False): controla se as predições e probabilidades serão salvas em CSV.
# - `nome_arquivo` (str, padrão='predicoes.csv'): nome do arquivo CSV para salvar as predições.
#
# ### Retorno
# - `preds`: array com predições binárias (0 ou 1).
# - `probs`: array com as probabilidades da classe positiva.
#
# ---
#
# ## Função `avaliar_predicoes`
#
# ### Descrição
# Avalia as predições binárias geradas, exibindo métricas importantes para análise de desempenho do modelo.
#
# ### Parâmetros
# - `y_true`: array com as classes verdadeiras (rótulos).
# - `preds`: array com as predições binárias geradas.
#
# ### Métricas apresentadas
# - Relatório completo de classificação (precision, recall, f1-score).
# - Matriz de confusão.
# - Acurácia geral do modelo.
#
# ---
#
# ## Exemplo de Uso
#
# ```python
# # Definir o threshold desejado
# threshold_escolhido = 0.4
#
# # Gerar predições com threshold customizado e salvar em CSV
# y_pred_custom, y_prob_custom = predizer_com_threshold(
#     modelo=grid_search.best_estimator_,
#     X=X_test_prep,
#     threshold=threshold_escolhido,
#     salvar_csv=True
# )
#
# # Avaliar as predições em relação aos valores reais
# avaliar_predicoes(y_test, y_pred_custom)
#
# # Mostrar caminho absoluto do arquivo salvo
# import os
# nome_arquivo = 'predicoes.csv'
# print("Arquivo será salvo em:", os.path.abspath(nome_arquivo))

# %% [markdown]
# [🔝 Voltar ao Sumário](#indice)

# %% [markdown]
# <a name="etapa-29-predição-e-avaliação-com-threshold-personalizado-e-salvamento-em-csv"></a>
# ## 🔍 Etapa 29: Predição e Avaliação com Threshold Personalizado e Salvamento em CSV

# %% [markdown]
# Este conjunto de funções permite realizar predições ajustando o threshold para converter probabilidades em classes binárias, além de avaliar o desempenho das predições e salvar os resultados em arquivo CSV.
#
# ---
#
# ## Função `predizer_com_threshold`
#
# ### Objetivo
# Realizar predições com um limiar personalizado e retornar tanto as predições binárias quanto as probabilidades previstas. Opcionalmente, salva os resultados em um arquivo CSV para análise posterior.
#
# ### Parâmetros
# - `modelo`: modelo treinado que possua o método `predict_proba`.
# - `X`: matriz ou DataFrame com as features pré-processadas para a predição.
# - `threshold` (float, padrão=0.5): valor de corte para transformar probabilidades em classes (0 ou 1).
# - `salvar_csv` (bool, padrão=False): indica se as predições e probabilidades devem ser salvas em arquivo CSV.
# - `nome_arquivo` (str, padrão='predicoes.csv'): nome do arquivo CSV onde os resultados serão salvos.
#
# ### Retorno
# - `preds`: array contendo as predições binárias (0 ou 1).
# - `probs`: array com as probabilidades da classe positiva.
#
# ---
#
# ## Função `avaliar_predicoes`
#
# ### Objetivo
# Avaliar e imprimir métricas de desempenho baseadas nas predições binárias geradas pelo modelo, utilizando os valores verdadeiros.
#
# ### Parâmetros
# - `y_true`: array com os valores reais das classes.
# - `preds`: array contendo as predições binárias do modelo.
#
# ### Métricas exibidas
# - Relatório de classificação (precision, recall, f1-score).
# - Matriz de confusão.
# - Acurácia do modelo.
#
# ---
#
# ## Exemplo de Uso
#
# ```python
# # Definir o threshold desejado para as predições
# threshold_escolhido = 0.4
#
# # Gerar predições com threshold customizado e salvar em CSV
# y_pred_custom, y_prob_custom = predizer_com_threshold(
#     modelo=grid_search.best_estimator_,
#     X=X_test_prep,
#     threshold=threshold_escolhido,
#     salvar_csv=True
# )
#
# # Avaliar as predições com os rótulos verdadeiros
# avaliar_predicoes(y_test, y_pred_custom)
#
# # Mostrar o caminho absoluto do arquivo CSV salvo
# import os
# nome_arquivo = 'predicoes.csv'
# print("Arquivo será salvo em:", os.path.abspath(nome_arquivo))

# %%
from sklearn.metrics import classification_report, confusion_matrix, accuracy_score

def predizer_com_threshold(modelo, X, threshold=0.5, salvar_csv=False, nome_arquivo='predicoes.csv'):
    """
    Realiza predição com threshold customizado, avalia e salva resultados.

    Parâmetros:
    - modelo: modelo treinado com método predict_proba
    - X: features pré-processadas para predição
    - threshold: float, limiar para converter probabilidades em classes
    - salvar_csv: bool, se True salva as predições em CSV
    - nome_arquivo: str, nome do arquivo CSV para salvar predições

    Retorna:
    - preds: array com predições binárias
    """
    # Pega probabilidades da classe positiva
    probs = modelo.predict_proba(X)[:, 1]

    # Aplica threshold customizado
    preds = (probs >= threshold).astype(int)

    # Avaliação só se houver rótulos verdadeiros (opcional)
    # Aqui assumimos que o usuário fornece X já separado para teste e tem y_test separado fora desta função
    # Caso queira passar y_test, podemos alterar a função

    if salvar_csv:
        df_result = pd.DataFrame({'probabilidade': probs, 'predicao': preds})
        df_result.to_csv(nome_arquivo, index=False)
        print(f'Predições salvas em {nome_arquivo}')

    return preds, probs

def avaliar_predicoes(y_true, preds):
    """
    Avalia as predições geradas e imprime relatório.

    Parâmetros:
    - y_true: array com valores verdadeiros
    - preds: array com predições binárias
    """
    print("Relatório de Classificação:")
    print(classification_report(y_true, preds))
    print("Matriz de Confusão:")
    print(confusion_matrix(y_true, preds))
    print("Acurácia:", accuracy_score(y_true, preds))

# Uso:

# Define threshold
threshold_escolhido = 0.4

# Prediz com threshold customizado
y_pred_custom, y_prob_custom = predizer_com_threshold(grid_search.best_estimator_, X_test_prep, threshold=threshold_escolhido, salvar_csv=True)

# Avalia com os dados verdadeiros
avaliar_predicoes(y_test, y_pred_custom)

import os

nome_arquivo = 'predicoes.csv'
print("Arquivo será salvo em:", os.path.abspath(nome_arquivo))
# Out:
# Predições salvas em predicoes.csv
# Relatório de Classificação:
#               precision    recall  f1-score   support
#
#            0       0.90      0.75      0.82      1552
#            1       0.53      0.78      0.63       561
#
#     accuracy                           0.75      2113
#    macro avg       0.71      0.76      0.72      2113
# weighted avg       0.80      0.75      0.77      2113
#
# Matriz de Confusão:
# [[1160  392]
#  [ 126  435]]
# Acurácia: 0.754850922858495
# Arquivo será salvo em: /content/predicoes.csv

# %% [markdown]
# [🔝 Voltar ao Sumário](#indice)

# %% [markdown]
# <a name="etapa-30-avaliação-de-métricas-em-vários-thresholds-e-visualização-gráfica"></a>
# ## 🔍 Etapa 30: Avaliação de Métricas em Vários Thresholds e Visualização Gráfica

# %% [markdown]
# Esta função permite avaliar as principais métricas de classificação para diferentes valores de threshold aplicados às probabilidades previstas pelo modelo. Os resultados são armazenados em um DataFrame, salvos em arquivo CSV e apresentados graficamente para facilitar a análise do impacto do threshold nas métricas.
#
# ---
#
# ## Função `avaliar_varios_thresholds`
#
# ### Objetivo
# Avaliar métricas de desempenho (Precision, Recall, F1 Score e Acurácia) do modelo para uma série de valores de threshold, possibilitando a escolha do melhor limiar para o problema em questão.
#
# ### Parâmetros
# - `modelo`: modelo treinado que possua o método `predict_proba`.
# - `X_test`: features de teste pré-processadas.
# - `y_test`: rótulos verdadeiros correspondentes a `X_test`.
# - `thresholds`: array ou lista de valores float representando os thresholds a serem avaliados (padrão: valores de 0.1 a 0.9 com passo 0.1).
#
# ### Retorno
# - `df_resultados`: DataFrame contendo as métricas calculadas para cada threshold.
#
# ---
#
# ## Funcionamento
# 1. Obtém as probabilidades previstas da classe positiva para todas as amostras de teste.
# 2. Para cada threshold especificado:
#    - Converte as probabilidades em predições binárias.
#    - Calcula as métricas Precision, Recall, F1 Score e Acurácia.
#    - Armazena os resultados em uma lista de dicionários.
# 3. Cria um DataFrame a partir dos resultados.
# 4. Salva o DataFrame em um arquivo CSV chamado `'avaliacao_thresholds.csv'`.
# 5. Plota as métricas em função do threshold para visualização clara das tendências.
# 6. Retorna o DataFrame com os resultados para uso posterior.
#
# ---
#
# ## Visualização
#
# O gráfico gerado mostra as curvas de Precision, Recall, F1 Score e Acurácia em função dos diferentes thresholds testados, permitindo identificar visualmente qual threshold oferece o melhor equilíbrio entre as métricas.
#
# ---
#
# ## Exemplo de Uso
#
# ```python
# df_avaliacao = avaliar_varios_thresholds(grid_search.best_estimator_, X_test_prep, y_test)
#
# print(df_avaliacao)

# %%
from sklearn.metrics import precision_score, recall_score, f1_score, accuracy_score

def avaliar_varios_thresholds(modelo, X_test, y_test, thresholds=np.arange(0.1, 1.0, 0.1)):
    resultados = []

    probs = modelo.predict_proba(X_test)[:,1]

    for thr in thresholds:
        preds = (probs >= thr).astype(int)
        precision = precision_score(y_test, preds)
        recall = recall_score(y_test, preds)
        f1 = f1_score(y_test, preds)
        acc = accuracy_score(y_test, preds)
        resultados.append({
            'threshold': thr,
            'precision': precision,
            'recall': recall,
            'f1_score': f1,
            'accuracy': acc
        })

    df_resultados = pd.DataFrame(resultados)

    # Salvar CSV
    df_resultados.to_csv('avaliacao_thresholds.csv', index=False)
    print("Resultados salvos em 'avaliacao_thresholds.csv'")

    # Plotar
    plt.figure(figsize=(10,6))
    plt.plot(df_resultados['threshold'], df_resultados['precision'], marker='o', label='Precision')
    plt.plot(df_resultados['threshold'], df_resultados['recall'], marker='o', label='Recall')
    plt.plot(df_resultados['threshold'], df_resultados['f1_score'], marker='o', label='F1 Score')
    plt.plot(df_resultados['threshold'], df_resultados['accuracy'], marker='o', label='Accuracy')
    plt.xlabel('Threshold')
    plt.ylabel('Score')
    plt.title('Métricas vs Threshold')
    plt.grid(True)
    plt.legend()
    plt.show()

    return df_resultados

# Exemplo de uso:
df_avaliacao = avaliar_varios_thresholds(grid_search.best_estimator_, X_test_prep, y_test)

print(df_avaliacao)
# Out:
# Resultados salvos em 'avaliacao_thresholds.csv'
# /usr/local/lib/python3.11/dist-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning:
#
# Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#    threshold  precision    recall  f1_score  accuracy
# 0        0.1   0.334142  0.982175  0.498643  0.475627
# 1        0.2   0.402308  0.932264  0.562063  0.614292
# 2        0.3   0.470817  0.862745  0.609188  0.706105
# 3        0.4   0.525998  0.775401  0.626801  0.754851
# 4        0.5   0.568690  0.634581  0.599832  0.775201
# 5        0.6   0.638756  0.475936  0.545455  0.789399
# 6        0.7   0.736607  0.294118  0.420382  0.784666
# 7        0.8   0.830508  0.087344  0.158065  0.752958
# 8        0.9   0.000000  0.000000  0.000000  0.734501

# %% [markdown]
# [🔝 Voltar ao Sumário](#indice)

# %% [markdown]
# <a name="etapa-31-relatório-de-análise-dos-thresholds-para-previsão-de-churn--telecomx"></a>
# ## 📊 Etapa 31: Relatório de Análise dos Thresholds para Previsão de Churn – TelecomX

# %% [markdown]
# ### ✅ Objetivo
#
# O objetivo é encontrar o **melhor limiar de decisão (threshold)** para classificar corretamente os clientes que irão cancelar (churn). Como se trata de um **problema de churn prediction**, damos mais importância a:
#
# - **Recall alto da classe 1 (churners)** → Identificar a maioria dos clientes que vão sair.
# - **F1-score balanceado** → Compromisso entre detectar churn e evitar falsos positivos.
# - **Precision razoável** → Evitar gastar recursos em clientes que não cancelariam.
#
# ---
#
# ### 📋 Tabela Resumo das Métricas por Threshold
#
# | Threshold | Precision | Recall | F1-score | Accuracy | Comentário |
# |-----------|-----------|--------|----------|----------|------------|
# | **0.1**   | 0.33      | **0.98** | 0.50     | 0.48     | Altíssimo recall, mas muitos falsos positivos. Inviável. |
# | **0.2**   | 0.40      | **0.93** | 0.56     | 0.61     | Ainda muitos falsos positivos. |
# | **0.3**   | 0.47      | **0.86** | 0.61     | 0.71     | 🔸 Equilíbrio inicial aceitável. |
# | **0.4**   | 0.53      | 0.77     | **0.63** | 0.75     | ✅ Melhor F1-score até aqui, bom recall. Ideal para churn. |
# | **0.5**   | 0.57      | 0.63     | 0.60     | 0.78     | Cai o recall, sobe acurácia. |
# | **0.6**   | 0.64      | 0.48     | 0.54     | 0.79     | Perde muito recall. |
# | **0.7**   | 0.73      | 0.29     | 0.42     | 0.78     | Recall muito baixo. |
# | **0.8**   | 0.83      | 0.09     | 0.16     | 0.75     | Ruim para churn. |
# | **0.9**   | 0.00      | 0.00     | 0.00     | 0.73     | Ignora classe 1. |
#
# ---
#
# ### 🟩 Conclusão: Melhor Threshold
#
# O **threshold ideal é 0.4**, pois apresenta o melhor equilíbrio:
#
# - **Precision:** 0.53
# - **Recall:** 0.77 ✅
# - **F1-score:** **0.63** (melhor entre os thresholds testados)
# - **Accuracy:** 0.75
#
# 🔍 **Motivo**: Excelente capacidade de capturar churners (alta sensibilidade) sem comprometer demais a precisão. Ideal para tomada de decisão proativa por parte da equipe da BRA TeleCOM.
#
# ---
#
# ### 📌 Recomendação
#
# Utilizar **threshold = 0.4** para classificar os clientes como churners.
# Opcionalmente, monitorar clientes com probabilidade entre **0.4 e 0.6** como grupo de **atenção especial**.
#
# ---

# %% [markdown]
# [🔝 Voltar ao Sumário](#indice)
